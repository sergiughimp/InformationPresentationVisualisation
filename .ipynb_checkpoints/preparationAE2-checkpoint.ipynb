# %%
import pandas as pd

# Load dataset
# https://www.kaggle.com/code/isaienkov/nba-2k20-data-analysis-visualization/notebook
df = pd.read_csv("nba2k20-full.csv")

print(df.shape)
df.isnull().sum()
# Out:
# (429, 14)
# full_name       0
# rating          0
# jersey          0
# team           23
# position        0
# b_day           0
# height          0
# weight          0
# salary          0
# country         0
# draft_year      0
# draft_round     0
# draft_peak      0
# college        66
# dtype: int64

# %%
df.head()
# Out:
#                full_name  rating jersey                  team position  \
# 0           LeBron James      97    #23    Los Angeles Lakers        F
# 1          Kawhi Leonard      97     #2  Los Angeles Clippers        F
# 2  Giannis Antetokounmpo      96    #34       Milwaukee Bucks      F-G
# 3           Kevin Durant      96     #7         Brooklyn Nets        F
# 4           James Harden      96    #13       Houston Rockets        G
#
#       b_day       height                weight     salary country  draft_year  \
# 0  12/30/84   6-9 / 2.06  250 lbs. / 113.4 kg.  $37436858     USA        2003
# 1  06/29/91   6-7 / 2.01  225 lbs. / 102.1 kg.  $32742000     USA        2011
# 2  12/06/94  6-11 / 2.11  242 lbs. / 109.8 kg.  $25842697  Greece        2013
# 3  09/29/88  6-10 / 2.08  230 lbs. / 104.3 kg.  $37199000     USA        2007
# 4  08/26/89   6-5 / 1.96   220 lbs. / 99.8 kg.  $38199000     USA        2009
#
#   draft_round draft_peak          college
# ...

# %%
# Select only 'team' and 'college' columns
team_college = df[['full_name','team', 'college']]

print(team_college.tail(60))
# Out:
#                   full_name                    team             college
# 369             Frank Mason         Milwaukee Bucks              Kansas
# 370            Ben McLemore         Houston Rockets              Kansas
# 371             Dzanan Musa           Brooklyn Nets                 NaN
# 372              Elie Okobo            Phoenix Suns                 NaN
# 373         Jerome Robinson      Washington Wizards      Boston College
# 374          JaKarr Sampson          Indiana Pacers          St. John's
# 375           Edmond Sumner          Indiana Pacers              Xavier
# 376           Gary Trent Jr  Portland Trail Blazers                Duke
# 377           Moritz Wagner      Washington Wizards            Michigan
# 378       Admiral Schofield      Washington Wizards           Tennessee
# 379          Bruno Fernando           Atlanta Hawks            Maryland
# 380          Alen Smailagic   Golden State Warriors                 NaN
# ...
